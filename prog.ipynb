# %%
import csv
import json

# Load from CSV and convert to JSON structure
def convert_csv_to_json(csv_file, json_file):
    with open(csv_file, mode='r', encoding='utf-8') as f:
        reader = csv.DictReader(f)
        jobs = []

        for row in reader:
            job = {
                "title": row["Job Title"].strip(),
                "description": row["description"].strip() if "description" in row else "",
                "skills": [skill.strip().lower() for skill in row["Key Skills"].split(",")]
            }
            jobs.append(job)

    # Save to JSON file (optional)
    with open(json_file, mode='w', encoding='utf-8') as f:
        json.dump(jobs, f, indent=4)

    return jobs

# Example usage
csv_file_path = 'jobss_cleaned.csv'
json_file_path = 'final_jobs.json'
result = convert_csv_to_json(csv_file_path, json_file_path)

# Print result
print(json.dumps(result, indent=4))
# Out:
# [
#     {
#         "title": "Digital Media Planner",
#         "description": "",
#         "skills": [
#             "media planning| digital media"
#         ]
#     },
#     {
#         "title": "Online Bidding Executive",
#         "description": "",
#         "skills": [
#             "pre sales| closing| software knowledge| clients| requirements| negotiating| client| online bidding| good communication| technology"
#         ]
#     },
#     {
#         "title": "Trainee Research/ Research Executive- Hi- Tech Operations",
#         "description": "",
#         "skills": [
#             "computer science| fabrication| quality check| intellectual property| electronics| support services| research| management| human resource management| research executive"
#         ]
#     },
#     {
#         "title": "Technical Support",
#         "description": "",
#         "skills": [
#             "technical support"
#         ]
#     },
#     {
#         "title": "Software Test Engineer -hyderabad",
#         "description": "",
#         "skills": [
#             "manual testing| test engineering| test cases| web testing| web technologies"
#         ]
#     },
#     {
#         "title": "Opening For Adobe Analytics Specialist",
#         "description": "",
#         "skills": [
#             "adobe experience manager| digital| digital marketing| adobe analytics| data analytics| aem| adobe| sitecatalyst"
#         ]
#     },
#     {
#         "title": "Sales- Fresher-for Leading Property Consultant",
#         "description": "",
#         "skills": [
#             "channel partners| real estate| negotiation| property| residential sales"
#         ]
#     },
#     {
#         "title": "Opportunity For Azure Devops Architect For Hyderabad Location",
#         "description": "",
#         "skills": [
#             "tfs| azure| git| vsts| docker| dynatrace| splunk| aws"
#         ]
#     },
#     {
#         "title": "BDE- PUNE",
#         "description": "",
#         "skills": [
#             "bde"
#         ]
#     },
#     {
#         "title": "Technical Support/ Product Support",
#         "description": "",
#         "skills": [
#             "technical support| support services| application support| communication skills| voice based process| semi voice| semi voice process"
#         ]
#     },
#     {
#         "title": "Executive Assistant To Chairman",
#         "description": "",
#         "skills": [
#             "secretary| executive assistant| ea"
#         ]
#     },
#     {
#         "title": "SEO Executive",
#         "description": "",
#         "skills": [
#             "website| web analytics| xml| link building| google analytics| case studies| seo| social media| tracking| maintaining"
#         ]
#     },
#     {
#         "title": "Workflow Coordinator",
#         "description": "",
#         "skills": [
#             "operations| workflow| tat| monitoring| mts| email"
#         ]
#     },
#     {
#         "title": "Oracle IDAM",
#         "description": "",
#         "skills": [
#             "oracle idam|oim|oam"
#         ]
#     },
#     {
#         "title": "Looking Facebook /social Media Manager For our Digital Marketing Ageny",
#         "description": "",
#         "skills": [
#             "digital marketing| seo| social media marketing| content marketing| email marketing| sem| google analytics| campaign management| facebook| media management"
#         ]
#     },
#     {
#         "title": "Wanted Engineering Fresher For MNC Chennai",
#         "description": "",
#         "skills": [
#             "instrumentation engineering| electrical engineering| engineering| fresher| trainee| immediate| mechanical engineering| electronics engineering| undergraduate"
#         ]
#     },
#     {
#         "title": "Tooling &amp; Sampling",
#         "description": "",
#         "skills": [
#             "help desk| customer service| customer relationship| access controls| asset management| vendor management"
#         ]
#     },
#     {
#         "title": "Account Manager",
#         "description": "",
#         "skills": [
#             "report generation| policies| analytical| procedures| analysts| data entry| analytical skills"
#         ]
#     },
#     {
#         "title": "Magento Developer",
#         "description": "",
#         "skills": [
#             "copyright| email| jquery| xml| javascript| cakephp| customer service| open source| facebook| css3"
#         ]
#     },
#     {
#         "title": "Looking For Trained Freshers in MS Dynamics CRM- Hyderabad",
#         "description": "",
#         "skills": [
#             "c#| ms dynamics crm| microsoft dynamics| ms dynamics"
#         ]
#     },
#     {
#         "title": "Job Openings Kotak Life/ Max Life/ Aditya Birla Health for Sales Mgr",
#         "description": "",
#         "skills": [
#             "sales manager| business development manager| relationship manager| brokers| insurance sales| channel sales| direct sale| direct marketing| sales| marketing executive| territory sales manager"
#         ]
#     },
#     {
#         "title": "Business Development / Corporate Sales",
#         "description": "",
#         "skills": [
#             "lead generation| business development| corporate sales"
#         ]
#     },
#     {
#         "title": "Business Development Manager (BDM)",
#         "description": "",
#         "skills": [
#             "contract management| closing| it services| relationship building| managed services| selling| market research| business development manager| sales"
#         ]
#     },
#     {
#         "title": "QA Executive",
#         "description": "",
#         "skills": [
#             "qa executive"
#         ]
#     },
#     {
#         "title": "Back End Java Developer - Restful Services/soap",
#         "description": "",
#         "skills": [
#             "java ee| jms| core java| junit| weblogic| html| jpa| json| soap| sql"
#         ]
#     },
#     {
#         "title": "Product Engineer",
#         "description": "",
#         "skills": [
#             "conceptualization| architecting| continuous improvement| side| development| front end| it"
#         ]
#     },
#     {
#         "title": "Opening For Articulate tool Developer - Articulate / Captivate)chennai",
#         "description": "",
#         "skills": [
#             "articulate storyline"
#         ]
#     },
#     {
#         "title": "Urgent Hiring for Area Sales Manager",
#         "description": "",
#         "skills": [
#             "area sales management| retail sales| fmcg| chocolate| confectionary| asm| area sales manager| area business manager"
#         ]
#     },
#     {
#         "title": "Software Engineer - C++ Development - Ooad/oops",
#         "description": "",
#         "skills": [
#             "c#| java| oop| c++| multithreading| uml| ooad| oops| .net| debugging"
#         ]
#     },
#     {
#         "title": "Linux Administrator Lead",
#         "description": "",
#         "skills": [
#             "qmail| workflow| nagios| windows server| networking| mysql| monitoring| redhat| maintaining| centos"
#         ]
#     },
#     {
#         "title": "Hiring for Tech Pm/scrum Master for Hyderabad Location",
#         "description": "",
#         "skills": [
#             "java| jpa| hibernate| project management| jdbc| scrum master| microservices| agile| soap| rest"
#         ]
#     },
#     {
#         "title": "Assistant Professor (Grade I)-Theoretical Computer Science",
#         "description": "",
#         "skills": [
#             "vide"
#         ]
#     },
#     {
#         "title": "US Based Financial Company Looking For Java API Engineers For HYD",
#         "description": "",
#         "skills": [
#             "java| java api| banking| j2ee| api| finance| core java| microservices"
#         ]
#     },
#     {
#         "title": "Strong Partner Ecosystem",
#         "description": "",
#         "skills": [
#             "gis| iso 27001| hr| information system| process| iso 9001| information security management| gis software| management| edge"
#         ]
#     },
#     {
#         "title": "Wordpress Web Developer",
#         "description": "",
#         "skills": [
#             "vide"
#         ]
#     },
#     {
#         "title": "Senior Executive- Contract Logistics- Bom WP-A",
#         "description": "",
#         "skills": [
#             "administration| administrative support| contract logistics| staff development| site management| quality improvement| warehousing| warehouse operations"
#         ]
#     },
#     {
#         "title": "Accounts Manager",
#         "description": "",
#         "skills": [
#             "filing| tds| service industry| pf| esi| returns| coaching| payroll| invoice| tally"
#         ]
#     },
#     {
#         "title": "Technical Sales Executive with fixed pay & lucrative incentives/UK Inb",
#         "description": "",
#         "skills": [
#             "outbound| antivirus| technical support| sales| spot| inbound calls| pay| medical| comp"
#         ]
#     },
#     {
#         "title": "nutanix sme",
#         "description": "",
#         "skills": [
#             "troubleshooting| dns| dhcp| monitoring| virtualization| shell scripting| python| vms| open source| archiving"
#         ]
#     },
#     {
#         "title": "System Architect - 3g/4g Wireless Network Architecture & Migration",
#         "description": "",
#         "skills": [
#             "4g| 3gpp| 3g| system architect| lte| radio access network| phd| ieee"
#         ]
#     },
#     {
#         "title": "Excellent Opportunity For \u201d Linux Device Driver \u201d ,for Hyderabad and Ban",
#         "description": "",
#         "skills": [
#             "arm processor|c|device drivers|embedded linux|linux kernel|ipc"
#         ]
#     },
#     {
#         "title": "Java Developer",
#         "description": "",
#         "skills": [
#             "jms| core java| sonar| weblogic| xml| j2ee| svn| spring| oracle 11g| sql"
#         ]
#     },
#     {
#         "title": "Regional Representative",
#         "description": "",
#         "skills": [
#             "market| presentation| strong analytical skills| english| presentation skills| developing| customer interaction"
#         ]
#     },
#     {
#         "title": "Hiring For Record To Report",
#         "description": "",
#         "skills": [
#             "fixed assets| accounts payable| record to report| general accounting| general ledger"
#         ]
#     },
#     {
#         "title": "Product & Regional Sales Manager",
#         "description": "",
#         "skills": [
#             "team management| regional sales| management"
#         ]
#     },
#     {
#         "title": "Senior Manager/associate Director - Mandarin",
#         "description": "",
#         "skills": [
#             "commercial activities| commercial sales| online sales| senior management| budgeting| strategy implementation| marketing| e - commerce"
#         ]
#     },
#     {
#         "title": "ODI Developer/lead ODI Developer - RACI",
#         "description": "",
#         "skills": [
#             "odi| matrix"
#         ]
#     },
#     {
#         "title": "UI Developer",
#         "description": "",
#         "skills": [
#             "javascript| sql| php| php mysql| css| software development| technical| photoshop| mca| ajax| jquery| application| web| design| mysql| html"
#         ]
#     },
#     {
#         "title": "Assistant Manager",
#         "description": "",
#         "skills": [
#             "relationship management| relationship building| client relationship| training| analytical skills| process mapping| standard operating procedures| agile| management| visa processing"
#         ]
#     },
#     {
#         "title": "Android Developer",
#         "description": "",
#         "skills": [
#             "android| btech| iphone| server| analytical| developing| ios| platforms| objective c| web| xml| design| json| programming| development| c| testing| mobile| xcode| application development| eclipse| application| sdk| applications"
#         ]
#     },
#     {
#         "title": "International BPO / Non Voice Process / Rotational Shift / Ahmedabad",
#         "description": "",
#         "skills": [
#             "cca| bpo| csr| international bpo| customer service| outbound process| customer care| tourism| customer support| fresher| voice process| inbound process| cse| bpo fresher| voice support| hotel| travel"
#         ]
#     },
#     {
#         "title": "iOS Developer",
#         "description": "",
#         "skills": [
#             "bca| graphics| application development| b tech| core| b sc| application| b e| ios| publishing| animation"
#         ]
#     },
#     {
#         "title": "F&A Black belt - Process Excellence Lead",
#         "description": "",
#         "skills": [
#             "accounting| continuous improvement| process improvement| load balancing| lean six sigma| black belt| training| green belt| process re - engineering| process excellence| business excellence| otc"
#         ]
#     },
#     {
#         "title": "IT - Head (preferably from an NGO)",
#         "description": "",
#         "skills": [
#             "networking| information technology| network administration| technical support| support services| license management| disaster recovery| data security| it training| it software"
#         ]
#     },
#     {
#         "title": "Digital Content Producer For largest Media House",
#         "description": "",
#         "skills": [
#             "automobile| digital content| content development| production| web content writing"
#         ]
#     },
#     {
#         "title": "Manager Holidays",
#         "description": "",
#         "skills": [
#             "tourism| target achievement| negotiation skills| revenue management| tour packages"
#         ]
#     },
#     {
#         "title": "Backend Developer",
#         "description": "",
#         "skills": [
#             "php| networking| data structures| http| json| software design| computer science| system design| backend| ticketing"
#         ]
#     },
#     {
#         "title": "JUNIOR BIG DATA ANALYST IN",
#         "description": "",
#         "skills": [
#             "vide"
#         ]
#     },
#     {
#         "title": "Chief Engineer",
#         "description": "",
#         "skills": [
#             "chief engineer| hospitality| hvac| maintenance| water treatment| energy conservation| capital expenditure"
#         ]
#     },
#     {
#         "title": "",
#         "description": "",
#         "skills": [
#             "marketing|executive|marketing|marketing|executive|direct|executives|marketing|executive|executive|executive|executive|marketing|executive|marketing|executive|direct|marketing|executive|marketing|executive|marketing|executive|executive|marketing|executive|direct|executive|direct|marketing|executive|executive|direct|marketing|marketing|executive"
#         ]
#     },
#     {
#         "title": "Oracle DBA Consultant - Data Guard/rac Modules",
#         "description": "",
#         "skills": [
#             "weblogic| configuration| mysql| installation| oracle dba| troubleshooting| oracle rac"
#         ]
#     },
#     {
#         "title": "Global HR Operations Analyst",
#         "description": "",
#         "skills": [
#             "service level| data management| hr coordinator| management audit| hr operations| human resource management"
#         ]
#     },
#     {
#         "title": "",
#         "description": "",
#         "skills": [
#             "manager|transformation|manager|transformation|manager|manager|manager|manager|transformation|manager|transformation|manager|manager|transformation|manager|manager|transformation|transformation|manager|manager|manager|manager|manager|manager|manager|manager|manager|manager|transformation|manager|manager|manager|manager|manager|manager|transformation|manager|manager|manager|manager|manager|manager|manager|transformation|manager|transformation|manager|manager|manager|transformation|manager|transformation|manager|manager|transformation|manager|manager|manager|manager|manager|manager|manager|manager|transformation"
#         ]
#     },
#     {
#         "title": "Compiler- Support Engineer",
#         "description": "",
#         "skills": [
#             "graphics| c++| windows os| linux| high performance computing| test cases| system software| gaming| freebsd"
#         ]
#     },
#     {
#         "title": "Key Accounts Manager",
#         "description": "",
#         "skills": [
#             "vide"
#         ]
#     },
#     {
#         "title": "Head Sales- Coworking Company",
#         "description": "",
#         "skills": [
#             "sales| team building| strategic leadership| real estate| field sales| sales strategy| enterprise business| go - to - market strategy| enterprise sales| sales executive activities| marketing"
#         ]
#     },
#     {
#         "title": "Clubhouse Manager, Facility Manager,",
#         "description": "",
#         "skills": [
#             "facility management| facility services"
#         ]
#     },
#     {
#         "title": "IP DRG / Surgery / ED / Denials Coders",
#         "description": "",
#         "skills": [
#             "sds| radiology| cpt| icd - 10| em| medical coding| coders| surgery| ed"
#         ]
#     },
#     {
#         "title": "Sales Manager - Education Sales",
#         "description": "",
#         "skills": [
#             "market analysis| public relations| cv| relationship building| market intelligence| prospecting| budgeting| sales process| branding"
#         ]
#     },
#     {
#         "title": "HR Associate",
#         "description": "",
#         "skills": [
#             "erp| mis| succession planning| reports| talent management| human resources| hr policies| recruitment| talent acquisition"
#         ]
#     },
#     {
#         "title": "Manager / Sr Manager - Digital Ad Sales - Ecommerce",
#         "description": "",
#         "skills": [
#             "revenue generation| marketing| ad sales| web technologies"
#         ]
#     },
#     {
#         "title": "Architect Junior/ Middle level",
#         "description": "",
#         "skills": [
#             "co ordination| team management| drafting| loans| online| coordination| quality"
#         ]
#     },
#     {
#         "title": "php developer",
#         "description": "",
#         "skills": [
#             "english| php| xml| dom| soap| com| web technologies| written communication| email| time"
#         ]
#     },
#     {
#         "title": "Openstack Engineer / Openstack Admin with Ceph Storage",
#         "description": "",
#         "skills": [
#             "cloud| puppet| python| git| kvm| linux| jenkins| openstack| ansible"
#         ]
#     },
#     {
#         "title": "Sr. Software Engineer",
#         "description": "",
#         "skills": [
#             "national| branch| vice president| j2ee| software"
#         ]
#     },
#     {
#         "title": "Software Engineering- Mentor",
#         "description": "",
#         "skills": [
#             "mentor| android| consulting| usage| development| software| mobile| it| side| front end| web technologies| coding| web| backend| open source| programming| investment"
#         ]
#     },
#     {
#         "title": "Application Tester",
#         "description": "",
#         "skills": [
#             "performance testing| software testing| manual testing| quality testing"
#         ]
#     },
#     {
#         "title": "Credit Control - Manager / Asst. Manager",
#         "description": "",
#         "skills": [
#             "pivot table| credit analysis| tally erp| accounting| vlookup| finance| lookup| advanced excel| hlookup| credit control"
#         ]
#     },
#     {
#         "title": "Night Shift - Non Voice / Web Chat - BPO",
#         "description": "",
#         "skills": [
#             "international bpo| bpo| kpo| web chat| non voice process| e mail| international call center| customer service representative| cse| interpersonal skills| ites| uk shift| customer service| e - commerce| customer care| customer support| bpo fresher"
#         ]
#     },
#     {
#         "title": "Sales Executive",
#         "description": "",
#         "skills": [
#             "innovative| aggressive"
#         ]
#     },
#     {
#         "title": "Design Engineer Mechanical",
#         "description": "",
#         "skills": [
#             "communication skills| detail engineering| material handling| autocad| detailing| design engineering| microstation| bid evaluation"
#         ]
#     },
#     {
#         "title": "Android developer",
#         "description": "",
#         "skills": [
#             "design| android| erp| software| mvc| quality"
#         ]
#     },
#     {
#         "title": "Technical Writer",
#         "description": "",
#         "skills": [
#             "technical writing| technical documentation| articles| writing skills| product support"
#         ]
#     },
#     {
#         "title": "Pro-Engineer , Matlab ,Ansys",
#         "description": "",
#         "skills": [
#             "ansys| thermal| matlab| system design| recruitment| mccb| electricals"
#         ]
#     },
#     {
#         "title": "Business Development Executive - Kolkata",
#         "description": "",
#         "skills": [
#             "product placement| market research| distributor handling| business development executive| customer service| customer service executive| secondary sales| supervision"
#         ]
#     },
#     {
#         "title": "Accountant - UK Based Accounting",
#         "description": "",
#         "skills": [
#             "management accounting| accounting| vat| book keeping| sage| tax returns"
#         ]
#     },
#     {
#         "title": "Opportunity For Current Account RM ||bank || Delhi",
#         "description": "",
#         "skills": [
#             "trade| forex trading| forex| fx| lead generation| accounting| banking| revenue generation| current account"
#         ]
#     },
#     {
#         "title": "PHP Developer",
#         "description": "",
#         "skills": [
#             "xml| javascript| php| development| css| technical| analytical| software| testing| html| tools| joomla| coding| jquery| web| mysql| wordpress| design| xhtml| debugging| ajax"
#         ]
#     },
#     {
#         "title": "Senior Engineering Maintenance Manager For Knitting and ZLD System",
#         "description": "",
#         "skills": [
#             "zld| engineering management| knitting"
#         ]
#     },
#     {
#         "title": "Accounting Specialist",
#         "description": "",
#         "skills": [
#             "analyst| erp| change management| business objects| managed services| business process mapping| executive management| data mining| oracle project accounting| testing"
#         ]
#     },
#     {
#         "title": "Manager (Service Operation)",
#         "description": "",
#         "skills": [
#             "erp| succession planning| mis| reports| talent management| human resources| hr policies| recruitment| talent acquisition"
#         ]
#     },
#     {
#         "title": "DevOps Engineer Intern",
#         "description": "",
#         "skills": [
#             "intern| linux| windows| unix| dns| c++| perl| iis| redhat| http"
#         ]
#     },
#     {
#         "title": "PHP Developer (wordpress & Woo Commerce/shopify / Magento)",
#         "description": "",
#         "skills": [
#             "c| woocommerce| magento| wordpress| mysql| php| shopify| jquery| web development| ajax"
#         ]
#     },
#     {
#         "title": "Java Developer",
#         "description": "",
#         "skills": [
#             "css| singleton| xml| javascript| jdbc| struts| json| html| spring boot| jquery"
#         ]
#     },
#     {
#         "title": "Sr. Manager- Business Development",
#         "description": "",
#         "skills": [
#             "business development management| bd| marketing| business development| projects| business development manager| bdm| tendering| proposal"
#         ]
#     },
#     {
#         "title": "Test Principal Engineer",
#         "description": "",
#         "skills": [
#             "ethical hacking| certified ethical hacker| networking protocols| penetration testing| nessus| nmap| fortify| vulnerability assessment| appscan| qualys"
#         ]
#     },
#     {
#         "title": "Graphic Designer",
#         "description": "",
#         "skills": [
#             "graphic designing| graphics| adobe creative suite| architecture| ms office| business executive"
#         ]
#     },
#     {
#         "title": "Business Development Executive",
#         "description": "",
#         "skills": [
#             "payment collection| costing| business development executive| lead generation| sales| vendor| cost"
#         ]
#     },
#     {
#         "title": "Animation Resident",
#         "description": "",
#         "skills": [
#             "internship| digital marketing| social media| relationship building| animation| creative| indesign| business executive| presentation skills| senior"
#         ]
#     },
#     {
#         "title": "Enterprise Business Development Representative",
#         "description": "",
#         "skills": [
#             "market penetration|marketing|customer satisfaction|enterprise business|web technologies|business development|strategy|aws|sales"
#         ]
#     },
#     {
#         "title": "Dot Net Developer",
#         "description": "",
#         "skills": [
#             "jquery| git| microsoft sql server| net asp net| software| testing| ado.net| microsoft| tools| sql| unit tests| database| application| web| design| .net| object oriented programming| support| programming"
#         ]
#     },
#     {
#         "title": "Urgent Opening for \"US Staffing Professionals\" - Noida",
#         "description": "",
#         "skills": [
#             "technical recruitment| us staffing| us recruitment| us recruiter| us it staffing| technical recruiter| it recruiter| recruiter| w2| c2c| talent acquisition| recruitment| staffing| sourcing"
#         ]
#     },
#     {
#         "title": "Front Office Executive-Noida",
#         "description": "",
#         "skills": [
#             "front office executive"
#         ]
#     },
#     {
#         "title": "Project Executive/coordinator",
#         "description": "",
#         "skills": [
#             "project administration| coordination"
#         ]
#     },
#     {
#         "title": "Sterling OMS Architect",
#         "description": "",
#         "skills": [
#             "order management system| sterling commerce| sterling| oms| sterling integrator| ecommerce| e - commerce"
#         ]
#     },
#     {
#         "title": "Dot net Developer",
#         "description": "",
#         "skills": [
#             "analytical| documentation| web development| algorithms| development| javascript| sql server| jquery| database| web| flex| design| mysql| net"
#         ]
#     },
#     {
#         "title": "Centreless Grinding Operator",
#         "description": "",
#         "skills": [
#             "nctvt"
#         ]
#     },
#     {
#         "title": "PHP Developer Jobs In Gurgaon - Team Lead - PHP",
#         "description": "",
#         "skills": [
#             "drupal| application programming| mysql| wordpress| php| cakephp| team leader| mvc| zend| software services"
#         ]
#     },
#     {
#         "title": "Sales Lead",
#         "description": "",
#         "skills": [
#             "outbound| sales| project management| analytical| sales lead| automation tools| sales process| marketing automation"
#         ]
#     },
#     {
#         "title": "Clerk - Garh Shankar (Vacancy-1)",
#         "description": "",
#         "skills": [
#             "vide"
#         ]
#     },
#     {
#         "title": "Senior Design Engineer - Manufacturing",
#         "description": "",
#         "skills": [
#             "autocad| 3d modeling| fmea| mechanical engineering| mechanical design| solidworks"
#         ]
#     },
#     {
#         "title": "Software Engineer Automation - Industrial Automation Job In Bangalore",
#         "description": "",
#         "skills": [
#             "automation engineer"
#         ]
#     },
#     {
#         "title": "Looking For Assistant Manager - Healthcare (US Visa is Must)",
#         "description": "",
#         "skills": [
#             "revenue cycle management| us healthcare| payment posting| medical billing| medical coding| us visa| team leading skills| healthcare| denial management| rcm"
#         ]
#     },
#     {
#         "title": "Senior Accounts Executive",
#         "description": "",
#         "skills": [
#             "vide"
#         ]
#     },
#     {
#         "title": "QA for Voice Process (LE-0097-N1C)",
#         "description": "",
#         "skills": [
#             "voice process| qaqc| writing| process operations| verbal"
#         ]
#     },
#     {
#         "title": "Senior Resident - Obs. & Gynae, Max Hospital, Gurgaon",
#         "description": "",
#         "skills": [
#             "patient care| nursing| people orientation| report generation| service quality| disaster management| customer care| medical| process orientation"
#         ]
#     },
#     {
#         "title": "",
#         "description": "",
#         "skills": [
#             "vide"
#         ]
#     },
#     {
#         "title": "Manager/senior Manager- Analytics- Life & Annuities - Insurance Domain",
#         "description": "",
#         "skills": [
#             "predictive modeling| sas| data management| data mining| tableau| data analytics| statistics| analytics| sql| python"
#         ]
#     },
#     {
#         "title": "Executive Medical Coder",
#         "description": "",
#         "skills": [
#             "molecular biology| chemistry| biotechnology| bhms| biology| physiotherapy| microbiology| nursing| biomedical| physics| medical coding| biochemistry| pharmacy| ophthalmology| micro biology| bioinformatics| zoology| biotech"
#         ]
#     },
#     {
#         "title": "Account Assistant",
#         "description": "",
#         "skills": [
#             "accounts executive| accountant| stock management| gst| auditing| statutory compliance| accounting| account assistant| bank reconciliation| tax audit| banking| monthly reports| payroll| salary processing| income tax| income tax return| taxation"
#         ]
#     },
#     {
#         "title": "Informatica Faculty Job Requirement in Hyderabad",
#         "description": "",
#         "skills": [
#             "informatica power center| informatica"
#         ]
#     },
#     {
#         "title": "SEO Expert/ Digital Marketing Gurgaon",
#         "description": "",
#         "skills": [
#             "digital marketing| seo specialist| advertising agency| online marketing| seo| seo expert| facebook marketing"
#         ]
#     },
#     {
#         "title": "Head Engineering",
#         "description": "",
#         "skills": [
#             "validation| installation| breakdown maintenance| industrial safety| gmp| boiler| design| hvac| gensets| air compressor| breakdown| ro| who"
#         ]
#     },
#     {
#         "title": "Business Development Executive",
#         "description": "",
#         "skills": [
#             "forecasting"
#         ]
#     },
#     {
#         "title": "PPC Executive",
#         "description": "",
#         "skills": [
#             "pay per click| google adwords| search engine marketing| ppc| sem| google analytics| website analysis| yahoo| web analytics| marketing initiatives"
#         ]
#     },
#     {
#         "title": "Opening For the post of Mr/territory Business Manager in An Pharma",
#         "description": "",
#         "skills": [
#             "marketing officer| pharma sales| marketing representative| marketing executive| pharma marketing| sales officer| sales representative| business development executive| fresher| trainee| sales executive"
#         ]
#     },
#     {
#         "title": "Deputy Manager - Program Management",
#         "description": "",
#         "skills": [
#             "project management| ppap| automotive| external audit| conflict resolution| resource mobilization| pfmea| risk management| project life cycle"
#         ]
#     },
#     {
#         "title": "Public Relations Manager - Bangalore",
#         "description": "",
#         "skills": [
#             "pr| public relations| media relations| social media| marketing communication| corporate communication| media relation| corp comm| online media| public relation| journalism| advertising| mass communication"
#         ]
#     },
#     {
#         "title": "Female Fresher's Counsellor- Gurgaon",
#         "description": "",
#         "skills": [
#             "counselling| couselling| fresher| student counsellor| student counseling"
#         ]
#     },
#     {
#         "title": "BE Chemical - Fresher",
#         "description": "",
#         "skills": [
#             "help desk| customer service| customer relationship| access controls| asset management| vendor management"
#         ]
#     },
#     {
#         "title": "Senior .Net Developer For Leading IT Company in Gurgaon",
#         "description": "",
#         "skills": [
#             "asp dot net| .net developer| dot net developer| asp.net| asp . net"
#         ]
#     },
#     {
#         "title": "Hiring a Valuation Associate (female Only)",
#         "description": "",
#         "skills": [
#             "secondary research| valuation| finance| real estate| primary| report preparation| business development| due diligence| financial modelling"
#         ]
#     },
#     {
#         "title": "Merchandising & Marketing- Professor",
#         "description": "",
#         "skills": [
#             "teaching| educator| counselor| mentor| trainer| advisor"
#         ]
#     },
#     {
#         "title": "Medical Transcriber",
#         "description": "",
#         "skills": [
#             "x - ray| medical transcription| ultrasound| ct scan"
#         ]
#     },
#     {
#         "title": "PHP Developer",
#         "description": "",
#         "skills": [
#             "cms| javascript| wordpress| drupal| joomla| ajax| cakephp| zend| knowledge| xhtml"
#         ]
#     },
#     {
#         "title": "Business Development Manager",
#         "description": "",
#         "skills": [
#             "sales| management| sales management| educational sales"
#         ]
#     },
#     {
#         "title": "Looking for a Job Change With a good package",
#         "description": "",
#         "skills": [
#             "outbound| antivirus| technical support| technical support associate| process| sales| inbound calls| us shift| comp"
#         ]
#     },
#     {
#         "title": "Huge Requirement for Customer Care Executive with Fixed Salary",
#         "description": "",
#         "skills": [
#             "technical support| english| comp| customer care executive| inbound calls| antivirus| issue| software"
#         ]
#     },
#     {
#         "title": "Assistant Manager \u2013 BI&I (data Automation)",
#         "description": "",
#         "skills": [
#             "c#|application development|senior level|ms sql|visual basic|power bi|msbi|ssis|recruitment|data integration"
#         ]
#     },
#     {
#         "title": "Field Sales Executive",
#         "description": "",
#         "skills": [
#             "escalation management| field sales executive| sales achievement| training| insurance sales"
#         ]
#     },
#     {
#         "title": "Sr. Manager Sales Capability Building",
#         "description": "",
#         "skills": [
#             "team management| salesforce| usage| sales| skill development| training| productivity improvement| training management| sales budgeting| tsi"
#         ]
#     },
#     {
#         "title": "Service Ops Expert - Servc Del | Microland",
#         "description": "",
#         "skills": [
#             "networking| unix| change management| scheduling| publishing| incident management| vmware| problem management| remedy| sip"
#         ]
#     },
#     {
#         "title": "Regional Trainer - Skin for Wellness & Beauty Industry (only Females)",
#         "description": "",
#         "skills": [
#             "planning| training| training manager| trainer| faculty"
#         ]
#     },
#     {
#         "title": "Sales Manager",
#         "description": "",
#         "skills": [
#             "sales| billing| ms office| business reporting| insurance sales| mis preparation| usage| corporate| networking| retail"
#         ]
#     },
#     {
#         "title": "Field Support Team-Supervisor",
#         "description": "",
#         "skills": [
#             "customer support| support service| field support| team| management| supervisor| self motivated| continuous improvement| give| enthusiastic"
#         ]
#     },
#     {
#         "title": "Sr. C# Developer",
#         "description": "",
#         "skills": [
#             "javascript| sql| xml| server| css| technical| software| developing| html| tracking| database| web| application development| net| programming| ajax| development| dom| solid| data integrity| stored procedures| reporting tools| application| applications"
#         ]
#     },
#     {
#         "title": "Sr Structural Engineer",
#         "description": "",
#         "skills": [
#             "senior design engineer| engineering design| sacs"
#         ]
#     },
#     {
#         "title": "IT Security Head",
#         "description": "",
#         "skills": [
#             "c| python| six sigma| pmp| .net| html| javascript| sql| oracle| assembly language| real time operating systems"
#         ]
#     },
#     {
#         "title": "Technical Support Executive",
#         "description": "",
#         "skills": [
#             "technical support executive| electrical engineering"
#         ]
#     },
#     {
#         "title": "Analyst - Business Intelligence",
#         "description": "",
#         "skills": [
#             "data analysis| automation| google analytics| excel| analytical| business intelligence| analytics| product marketing| sql| data extraction"
#         ]
#     },
#     {
#         "title": "Nokia WING Circuit Core - SMSC Engineer",
#         "description": "",
#         "skills": [
#             "detail design|juniper|smsc engineer|routing|ip networking|network elements|network troubleshooting|high level design|data center|switching"
#         ]
#     },
#     {
#         "title": "Assistant Restaurant Manager / Restaurant Manager",
#         "description": "",
#         "skills": [
#             "assistant restaurant manager| restaurant| restaurant manager"
#         ]
#     },
#     {
#         "title": "Digital / Web Artist",
#         "description": "",
#         "skills": [
#             "layout| visualization| digital media| graphic design| html| illustration| tools| part time"
#         ]
#     },
#     {
#         "title": "Business Development Manager",
#         "description": "",
#         "skills": [
#             "selling| accounts| events| prospecting| business operations| ideas| coordinating| tracking| closing| maintaining"
#         ]
#     },
#     {
#         "title": "Web/ GUI Designer",
#         "description": "",
#         "skills": [
#             "photoshop| illustrator| seo| jquery| fireworks| css3| gui| usability| development| static"
#         ]
#     },
#     {
#         "title": "Web Designer - Html, CSS, Bootstrap, Photoshop",
#         "description": "",
#         "skills": [
#             "photoshop| html| wordpress| css3| bootstrap| web technologies| html5| css"
#         ]
#     },
#     {
#         "title": "Python Developer",
#         "description": "",
#         "skills": [
#             "python"
#         ]
#     },
#     {
#         "title": "Web Designer",
#         "description": "",
#         "skills": [
#             "server| multimedia| troubleshooting| graphics| audio| monitoring| javascript| jquery| user interface| css3"
#         ]
#     },
#     {
#         "title": "AVP- FX MO",
#         "description": "",
#         "skills": [
#             "senior management| mis reporting| building| training| management| risk| vice president| focus| trade| associate vice president"
#         ]
#     },
#     {
#         "title": "Cluster Sales Head - Tied Channel &amp; Affinity Alliances - Health Insura",
#         "description": "",
#         "skills": [
#             "sales head| tied channel| sales| business growth| profitability| business operations| new business| alliances"
#         ]
#     },
#     {
#         "title": "Head - Project Management",
#         "description": "",
#         "skills": [
#             "project management"
#         ]
#     },
#     {
#         "title": "Walk- In For Development QA/ Regulatory Affairs",
#         "description": "",
#         "skills": [
#             "qa| life sciences| development quality assurance| life cycle| regulatory affairs| dqa| qms| dmf"
#         ]
#     },
#     {
#         "title": "Manager Accounts-wazirpur-mba-finance-salary-35k(export House exp)",
#         "description": "",
#         "skills": [
#             "accounting| finance| financial reporting| statutory compliance| gst| vat"
#         ]
#     },
#     {
#         "title": "Team Leader- Head Digital Prtnrshp & BD",
#         "description": "",
#         "skills": [
#             "data analysis| consumer research| management| head business development"
#         ]
#     },
#     {
#         "title": "DWH Tester - Manual Testing",
#         "description": "",
#         "skills": [
#             "testing| quality| manual testing| etl| bi| dw| datawarehouse testing"
#         ]
#     },
#     {
#         "title": "Quality Assurance Engineer",
#         "description": "",
#         "skills": [
#             "assembly language| six sigma| pmp| c| javascript| .net| html| oracle| python| sql"
#         ]
#     },
#     {
#         "title": "Technical / Functional Skills",
#         "description": "",
#         "skills": [
#             "product management| business process| linkedin| automation| cv| email| git| technical| sdlc| ideas"
#         ]
#     },
#     {
#         "title": "Software Development / Software Engineer",
#         "description": "",
#         "skills": [
#             "ajax| javascript| php| erp| website| development| software development| module| mca| application development| application| web| programming"
#         ]
#     },
#     {
#         "title": "",
#         "description": "",
#         "skills": [
#             "vide"
#         ]
#     },
#     {
#         "title": "Inbound Phone Banking Voice Process - Leading Bank - Noida",
#         "description": "",
#         "skills": [
#             "customer service| customer care| team| communication| bpo| call center| inbound| voice| backend| non voice| telecalling| cse| cro| cce| data entry| back office| voice process| domestic bpo| fresher| trainee| telemarketing| outbound| sales| hardware| networking"
#         ]
#     },
#     {
#         "title": "Java Enterprise Edition",
#         "description": "",
#         "skills": [
#             "oracle|core java|business process|outsourcing|operations|spring integration|j2ee|spring framework|jee|manager technology"
#         ]
#     },
#     {
#         "title": "Associate Clinical Data Processor",
#         "description": "",
#         "skills": [
#             "ms office| data entry"
#         ]
#     },
#     {
#         "title": "",
#         "description": "",
#         "skills": [
#             "sales|counter|sales|sales|sales|sales|counter|sales|sales|sales|counter|sales|sales|counter|sales|sales|sales|sales|sales|counter|sales|sales|sales|sales|counter|sales|sales|sales|sales|sales|sales|counter|sales|sales|sales|sales|sales|sales|sales|sales|sales|sales|counter|sales"
#         ]
#     },
#     {
#         "title": "CRM",
#         "description": "",
#         "skills": [
#             "customer relationship| automobile| proposal preparation| crm strategy| architecture| database| testing"
#         ]
#     },
#     {
#         "title": "Magento Developer",
#         "description": "",
#         "skills": [
#             "unix| version control| prototype| xml| mysql| php| json| mvc| ajax| css3"
#         ]
#     },
#     {
#         "title": "Merchandiser",
#         "description": "",
#         "skills": [
#             "merchandising| buyer activities| follow ups| vendor| purchase| vendor development| tracking"
#         ]
#     },
#     {
#         "title": "SIEM Analyst",
#         "description": "",
#         "skills": [
#             "vide"
#         ]
#     },
#     {
#         "title": "Hiring ll Azure Devops and Management Lead ll Hyderabad",
#         "description": "",
#         "skills": [
#             "c#| azure| powershell| script writing| api| debugging| devops| application integration"
#         ]
#     },
#     {
#         "title": "Senior Faculty - Information Design",
#         "description": "",
#         "skills": [
#             "vide"
#         ]
#     },
#     {
#         "title": "computer operator",
#         "description": "",
#         "skills": [
#             "computer operator| ms office| software services| comm| typing speed| who| software| level"
#         ]
#     },
#     {
#         "title": "Operation Executive",
#         "description": "",
#         "skills": [
#             "operations management| mobilization| resource mobilization| general management| interview| recruitment"
#         ]
#     },
#     {
#         "title": "Customer Support Executive",
#         "description": "",
#         "skills": [
#             "customer support executive| customer service| business executive| process"
#         ]
#     },
#     {
#         "title": "Corporate-Day Care Manager.",
#         "description": "",
#         "skills": [
#             "staff training| day care| recruitment"
#         ]
#     },
#     {
#         "title": "Hiring going on for .US Inbound Tech Support/ Sales",
#         "description": "",
#         "skills": [
#             "process| spot| technical support| night shift| international bpo"
#         ]
#     },
#     {
#         "title": "Deputy Manager- Performance/digital Marketing",
#         "description": "",
#         "skills": [
#             "digital marketing|email marketing|adwords|display advertising|digital campaigns|google analytics|sem|seo"
#         ]
#     },
#     {
#         "title": "Technical Lead -(VoIP,Cisco Call Manager)",
#         "description": "",
#         "skills": [
#             "java| cisco call manager| visa| j2ee| sip| offshore| communication skills"
#         ]
#     },
#     {
#         "title": "",
#         "description": "",
#         "skills": [
#             "vide"
#         ]
#     },
#     {
#         "title": "Relationship Manager",
#         "description": "",
#         "skills": [
#             "sales| business development| change management| mobile| mobiles| handset| mobile handset| marketing| relationship management| distribution management| channel management| dealer management| retailer"
#         ]
#     },
#     {
#         "title": "Technician, Technical Support",
#         "description": "",
#         "skills": [
#             "international call center| technical support| maintenance| communication skills| pc hardware| technician activities| social media| analytical ability| soft skills| customer satisfaction"
#         ]
#     },
#     {
#         "title": "Graphic Designer",
#         "description": "",
#         "skills": [
#             "illustrator| corel draw| photoshop"
#         ]
#     },
#     {
#         "title": "Consultant",
#         "description": "",
#         "skills": [
#             "manual testing| informatica| microsoft| process automation| system testing| pdf| artificial intelligence| regression testing| silicon| analytics"
#         ]
#     },
#     {
#         "title": "Immediate Requirement for Fusion Technical Lead Developer",
#         "description": "",
#         "skills": [
#             "technical architecture| fusion| oracle fusion"
#         ]
#     },
#     {
#         "title": "Layout Designer / Web Designer",
#         "description": "",
#         "skills": [
#             "layout design| corel draw| web designing| photoshop"
#         ]
#     },
#     {
#         "title": "International BPO- Mahindra- Meru- TATA SKY- Paddle Point-pepperfry-hc",
#         "description": "",
#         "skills": [
#             "bpo voice| voice process| international bpo"
#         ]
#     },
#     {
#         "title": "Asp.net with Angular JS & Html5 - Hyderabad",
#         "description": "",
#         "skills": [
#             "html5| asp"
#         ]
#     },
#     {
#         "title": "Sales Manager Product and Portfolio",
#         "description": "",
#         "skills": [
#             "product training| sales| relationship| banking| recruitment"
#         ]
#     },
#     {
#         "title": "Key Accounts Manager",
#         "description": "",
#         "skills": [
#             "customer profitability| receivable management| education| relationship building| transportation| service| monitoring| key accounts"
#         ]
#     },
#     {
#         "title": "Store Head-leading Manufacturing Company",
#         "description": "",
#         "skills": [
#             "stores| warehouse| logistics"
#         ]
#     },
#     {
#         "title": "BPO Inbound Voice Tech Process - Customer Service Inbound Voice - Appl",
#         "description": "",
#         "skills": [
#             "bpo| outbound| english| email| inbound calls| customer service| troubleshooting| technical support| recruitment| comp"
#         ]
#     },
#     {
#         "title": "Java Software Engineer",
#         "description": "",
#         "skills": [
#             "linux| agile| python| computer science| coding| fixed income| machine learning| asset management| jira| financial services"
#         ]
#     },
#     {
#         "title": "Admin Executive",
#         "description": "",
#         "skills": [
#             "english| ms office| admin executive| billing| stock inventory| writing| office management| management| business executive| application"
#         ]
#     },
#     {
#         "title": "Agm Finance for Automobile Company in Kolkata . Salary:7 Lpa",
#         "description": "",
#         "skills": [
#             "credit officers| risk management| administration| report generation| analysts| analytical skills"
#         ]
#     },
#     {
#         "title": "Accounts Manager (male)",
# ...
#         ]
#     },
#     {
#         "title": "Business Analyst - Structured Finance",
#         "description": "",
#         "skills": [
#             "electronic trading| structured finance| dcf| equity research| bloomberg| investment banking| business analysis| bonds| valuation| advanced excel| hedge fund| financial modelling| structured products| fixed income"
#         ]
#     },
#     {
#         "title": "Solution Architecting",
#         "description": "",
#         "skills": [
#             "product management|analytical skills|software architecture|prototype|business analysis|manager technology|outsourcing|resource management|operations|solution architecting"
#         ]
#     },
#     {
#         "title": "Sales / Business Development",
#         "description": "",
#         "skills": [
#             "sales head| hospitality| office automation| residential sales| sales strategy| bfsi| management| real estate sales| flex| executive search"
#         ]
#     },
#     {
#         "title": "Medical Coding Job(fresher Ug/pg) Pharm,lifescience,be(biotech&biomed)",
#         "description": "",
#         "skills": [
#             "biotechnology| microbiology| nursing| biomedical| medical coding| medical coder| pharmacy| life sciences"
#         ]
#     },
#     {
#         "title": "Consultant",
#         "description": "",
#         "skills": [
#             "com| application support| email| sap is-utilities| level| billing| change| service| crm| entry level"
#         ]
#     },
#     {
#         "title": "Network & Security Architect- Pune",
#         "description": "",
#         "skills": [
#             "network"
#         ]
#     },
#     {
#         "title": "Business Development Manager",
#         "description": "",
#         "skills": [
#             "erp| rf| action plan| relationship| software sales| business planning| b2b sales| rfq| rfp| crm"
#         ]
#     },
#     {
#         "title": "Assistant Vice President - Stock Broking - Delhi",
#         "description": "",
#         "skills": [
#             "equity| currency| mutual funds| commodities| stock broking| new client acquisition| business generation| channel distribution| team management| team handling| sales"
#         ]
#     },
#     {
#         "title": "",
#         "description": "",
#         "skills": [
#             "java|trainer|java|trainer|trainer|java|trainer|java|trainer|java|trainer|java|trainer|java|trainer|java|trainer|java|trainer|java|trainer|java|trainer|java|trainer|java|trainer|java|trainer|java|trainer|java|trainer|java|trainer|trainer|trainer|trainer|java|trainer|java|trainer|trainer|java|java|trainer|java|trainer|java|trainer|java|trainer|java|trainer|java|trainer|trainer|trainer|trainer|trainer|trainer|trainer|trainer|java|java|java|trainer|java|java|java|trainer|java|java|java|trainer|java"
#         ]
#     },
#     {
#         "title": "Production Manager in Press Shop & Projection Welding",
#         "description": "",
#         "skills": [
#             "production management| weld shop| press shop| pressing| sheetmetal"
#         ]
#     },
#     {
#         "title": "salesfoce Developer +3Years / Mumbai",
#         "description": "",
#         "skills": [
#             "salesforce developer| sfdc developer| salesforce"
#         ]
#     },
#     {
#         "title": "Social Media Executive",
#         "description": "",
#         "skills": [
#             "website| facebook| online| twitter| seo| internet| search engine optimisation"
#         ]
#     },
#     {
#         "title": "Business Advisor",
#         "description": "",
#         "skills": [
#             "vide"
#         ]
#     },
#     {
#         "title": "IT Recruiter, Technical Recruiter",
#         "description": "",
#         "skills": [
#             "head hunting| talent acquisition| recruitment executive| it recruitment| screening| technical recruitment| hiring| recruitment consultant| recruitment| sourcing| excel powerpoint| staffing"
#         ]
#     },
#     {
#         "title": "SAP PLM Consultant - SAP MM Module",
#         "description": "",
#         "skills": [
#             "sap plm| sap mm| sap ehs"
#         ]
#     },
#     {
#         "title": "Python Manager - IIT/ IIM/ DSE/ ISI",
#         "description": "",
#         "skills": [
#             "microstrategy| business intelligence| cognos| business objects| tableau| aws| python| sql"
#         ]
#     },
#     {
#         "title": "Marketing Manager - Activation - Iit/nit",
#         "description": "",
#         "skills": [
#             "marketing| event management| brand management"
#         ]
#     },
#     {
#         "title": "Hiring .Net Developers for Hyderabad Location",
#         "description": "",
#         "skills": [
#             "asp.net| ado.net| mvc"
#         ]
#     },
#     {
#         "title": "Senior BI Cognos Developer",
#         "description": "",
#         "skills": [
#             "sql| oracle| cognos| business intelligence| automotive| supply chain| dbmstools| metadata"
#         ]
#     },
#     {
#         "title": "Technical Support Engineer",
#         "description": "",
#         "skills": [
#             "technical support| san| veritas| data management| netbackup| windows os| webex| unix operating system| tcp/ip| it infrastructure"
#         ]
#     },
#     {
#         "title": "Senior Drupal Developer",
#         "description": "",
#         "skills": [
#             "drupal| linux| mysql| python| consulting| procurement| monitoring| front end| backend| django"
#         ]
#     },
#     {
#         "title": "Pre Sales Executive",
#         "description": "",
#         "skills": [
#             "presales| real estate sales| residential sales| sales executive activities"
#         ]
#     },
#     {
#         "title": "Head - Sales &amp; Strategy (telematics)",
#         "description": "",
#         "skills": [
#             "b2b sales| team management| kam| commercial vehicle| sales strategy| enterprises sales"
#         ]
#     },
#     {
#         "title": "Content Writer Required for a Monthly Magazine",
#         "description": "",
#         "skills": [
#             "editing| proof reading| content writer| editor| articles| article writing| content editor| journalism| mass communication| copywriter| associate editor| sub editor| english writing| research| social media"
#         ]
#     },
#     {
#         "title": "Sales Engineers",
#         "description": "",
#         "skills": [
#             "set| eee| interpersonal skills| selling| sales marketing| travel| marketing management| hardware"
#         ]
#     },
#     {
#         "title": "Senior Laravel Developer",
#         "description": "",
#         "skills": [
#             "mysql| wordpress| javascript| flex| cms| php| html| json| joomla| ajax"
#         ]
#     },
#     {
#         "title": "Medical Scribe Chandigarh Mohali Noida No Fees, Salary-26k To 48k",
#         "description": "",
#         "skills": [
#             "mbbs| b.sc| biotech| dermatology| rheumatology| ent| bds| medicine| pathology| immunology| medical transcription| radiology| genetics| bams| mds"
#         ]
#     },
#     {
#         "title": "Hub-Incharge Bangalore",
#         "description": "",
#         "skills": [
#             "help desk| customer service| customer relationship| access controls| asset management| vendor management"
#         ]
#     },
#     {
#         "title": "QA - Associate , - Business - Operations - DM",
#         "description": "",
#         "skills": [
#             "qa| data management| gdb| fixed income| data quality| http| operations| python"
#         ]
#     },
#     {
#         "title": "Staff Nurse",
#         "description": "",
#         "skills": [
#             "nursing| nicu| medical | patient care| nurse"
#         ]
#     },
#     {
#         "title": "Back Office Executive|data Entry Operators|domestic BPO",
#         "description": "",
#         "skills": [
#             "back office processing| bpo| part time| data entry| computer operator| backend| non voice| chat process| account| marketing| inbound process"
#         ]
#     },
#     {
#         "title": "Sr Equity Advisor - 5 nos",
#         "description": "",
#         "skills": [
#             "shares| market research| communication skills"
#         ]
#     },
#     {
#         "title": "Data Scientist - Sql/nosql",
#         "description": "",
#         "skills": [
#             "sql| nosql| r| python| scala| data visualization| machine learning| data science| data modeling| algorithm"
#         ]
#     },
#     {
#         "title": "Hiring For Day Shift Non Voice Sal. Up To 24K",
#         "description": "",
#         "skills": [
#             "international bpo| it helpdesk| freshers| customer care| international voice| call center| customer support| technical helpdesk| service desk| bpo fresher| uk| us| communication skills"
#         ]
#     },
#     {
#         "title": "",
#         "description": "",
#         "skills": [
#             "vide"
#         ]
#     },
#     {
#         "title": "React.js Developer",
#         "description": "",
#         "skills": [
#             "jquery| mysql| struts| javascript| database| jsf"
#         ]
#     },
#     {
#         "title": "Requirement in Private bank for BDE",
#         "description": "",
#         "skills": [
#             "business development| sales| bde| new business| business analyst| business development manager| business development executive| senior business analyst| sales manager| banker| private banker| sales officer"
#         ]
#     },
#     {
#         "title": "Physics- TGT",
#         "description": "",
#         "skills": [
#             "counselor| mentor| trainer| advisor| teaching"
#         ]
#     },
#     {
#         "title": "Technical Sales Executive -mumbai",
#         "description": "",
#         "skills": [
#             "sales engineer| technical sales| sales executive activities"
#         ]
#     },
#     {
#         "title": "Urgent Opening - Hp-ux Administrator",
#         "description": "",
#         "skills": [
#             "unix"
#         ]
#     },
#     {
#         "title": "Support Executive",
#         "description": "",
#         "skills": [
#             "interpersonal skills| direct marketing| it hardware| management| support executive"
#         ]
#     },
#     {
#         "title": "J. Stores - Manager",
#         "description": "",
#         "skills": [
#             "analytical skills| technical| educational qualification| stores| management| forecasting| electricals| inventory| cables| organization skills"
#         ]
#     },
#     {
#         "title": "Product Manager",
#         "description": "",
#         "skills": [
#             "product management| product pricing| sales| market research| user experience| marketting| asm| tsm| sales manager"
#         ]
#     },
#     {
#         "title": "",
#         "description": "",
#         "skills": [
#             "vide"
#         ]
#     },
#     {
#         "title": "Draughtsman",
#         "description": "",
#         "skills": [
#             "autocad| costing| draughtsman| civil| 3d"
#         ]
#     },
#     {
#         "title": "Senior Java Tech Lead - Spring Boot/ Data Structure",
#         "description": "",
#         "skills": [
#             "java| soa| tdd| saas| j2ee| spring boot| api| algorithm| data structure"
#         ]
#     },
#     {
#         "title": "BCOM (hiring for Top4) Internal Audit /compliance Call Vikas",
#         "description": "",
#         "skills": [
#             "mba finance| auditing| internal audit| sox| audit compliance| compliance"
#         ]
#     },
#     {
#         "title": "ETL Datastage Developer",
#         "description": "",
#         "skills": [
#             "technical management| agile methodology| unit testing| design development| business analytics| big data| sql queries| spark| performance tuning| test case design"
#         ]
#     },
#     {
#         "title": "Technical Lead",
#         "description": "",
#         "skills": [
#             "css| html5| mysql| javascript| bootstrap| json| node.js| jquery| core php| ajax"
#         ]
#     },
#     {
#         "title": "Specialist - DV",
#         "description": "",
#         "skills": [
#             "javascript| sql| python| design studio| strategy consulting| front end| big data analytics| qlikview| matlab"
#         ]
#     },
#     {
#         "title": "Office Assistant, Office Boy",
#         "description": "",
#         "skills": [
#             "tea| coffee| office assistance| admin| office assistant| computer operator"
#         ]
#     },
#     {
#         "title": "MES camster/apriso/hydra engineer",
#         "description": "",
#         "skills": [
#             "oracle database| server| vb.net| technical| tools| sql| sql server 2008| database| design| ms.net| application development| test cases| net| deployment| automation| development| c| oracle| testing| specification| vb| quality| application| plsql| pl| support| wip"
#         ]
#     },
#     {
#         "title": "HR PMO Professional",
#         "description": "",
#         "skills": [
#             "change management| excel| customer satisfaction| project management| relationship building| hr policies| hr| scheduling| visio| stakeholder management"
#         ]
#     },
#     {
#         "title": "Principal Consultant",
#         "description": "",
#         "skills": [
#             "business solutions| project delivery| conceptualization| green field projects| gap analysis| pdf| regulatory compliance| account mining| delivery lead| oracle retail"
#         ]
#     },
#     {
#         "title": "Urgent Requirment For Central Processing Center- Mumbai",
#         "description": "",
#         "skills": [
#             "accounting entries| debit| communication skills| finance| document verification| banking| problem solving| open office| dispute management"
#         ]
#     },
#     {
#         "title": "Cognos TM1 Developer (4 6 years)",
#         "description": "",
#         "skills": [
#             "sql server 2008| cognos| mvc| side| server| java| asp.net| javascript| problem| developer| asp.net mvc| sql"
#         ]
#     },
#     {
#         "title": "Smart Web Developer",
#         "description": "",
#         "skills": [
#             "java| java| business analysts| development| architects| html| lead developers| sql| xml| design| php| ios development| pl"
#         ]
#     },
#     {
#         "title": "Manager- Compensation and Benefits",
#         "description": "",
#         "skills": [
#             "vide"
#         ]
#     },
#     {
#         "title": "Civil Architect",
#         "description": "",
#         "skills": [
#             "architect| engineering design| epc| civil"
#         ]
#     },
#     {
#         "title": "Reconciliation Executive",
#         "description": "",
#         "skills": [
#             "access controls| technology| asset management| intellectual property| vendor management| crm"
#         ]
#     },
#     {
#         "title": "Oracle Sales Cloud Developer",
#         "description": "",
#         "skills": [
#             "oracle sales"
#         ]
#     },
#     {
#         "title": "Opening For Sales and Marketing_nariman Point",
#         "description": "",
#         "skills": [
#             "sales| marketing"
#         ]
#     },
#     {
#         "title": "Finance & OPS - Technical Consultant (dynamics Ax/365) @ Bangalore",
#         "description": "",
#         "skills": [
#             "microsoft dynamics ax| strategy implementation| proposal development| business development| resource planning| cost management| enterprise applications| data integrity| microsoft applications| process design| technical consultant"
#         ]
#     },
#     {
#         "title": "Business Development Manager-digital / Export",
#         "description": "",
#         "skills": [
#             "digital marketing| international sales| international marketing| international business development| business development| export marketing"
#         ]
#     },
#     {
#         "title": "Sr. Software Engineer",
#         "description": "",
#         "skills": [
#             "unix| pdf| deployment| informatica| oracle| teradata| troubleshooting| data warehousing"
#         ]
#     },
#     {
#         "title": "Website Designer",
#         "description": "",
#         "skills": [
#             "jquery| analytical| wordpress| conceptualization| web designing| photoshop| business executive| css3| ideas"
#         ]
#     },
#     {
#         "title": "Tech caller hiring a huge number of Executives.",
#         "description": "",
#         "skills": [
#             "outbound| night shift| recruitment| iphone| email| us shift| troubleshooting| technical support| comp| international bpo"
#         ]
#     }
# ]

# %%
import csv
import json

# Path to your CSV file
csv_path = 'job_details.csv'
output_json_path = 'skills_new.json'

unique_skills = set()

with open(csv_path, newline='', encoding='utf-8') as csvfile:
    reader = csv.DictReader(csvfile)
    
    for row in reader:
        raw_skills = row.get('Skills Required', '')
        if raw_skills:
            # Split using | delimiter
            skills_list = raw_skills.lower().split(',')
            for skill in skills_list:
                cleaned_skill = skill.strip()
                if cleaned_skill:
                    unique_skills.add(cleaned_skill)

# Convert set to sorted list
sorted_skills = sorted(unique_skills)

# Write to JSON
with open(output_json_path, 'w', encoding='utf-8') as jsonfile:
    json.dump(sorted_skills, jsonfile, indent=4)

print(f"Extracted {len(sorted_skills)} unique skills to {output_json_path}")
# Out:
# Extracted 793 unique skills to skills_new.json

# %%
import json

# Load jobs.json
with open('jobs.json', 'r', encoding='utf-8') as f:
    job_data = json.load(f)

# List of non-skills to exclude (e.g., perks)
exclude_phrases = {
    "free snacks", "free snacks & beverages", "informal dress code",
    "5 days a week", "health insurance", "certificate",
    "letter of recommendation", "job offer", "cab/transportation facility"
}

unique_skills = set()

# Go through each job
for job in job_data:
    skills_field = job.get("skills", [])
    
    # If it's a string, split by comma
    if isinstance(skills_field, str):
        skills = skills_field.split(',')
    elif isinstance(skills_field, list):
        skills = []
        for s in skills_field:
            if isinstance(s, str):
                skills.extend(s.split(','))  # In case it's still comma-separated
    else:
        continue  # Skip if not a list or string

    for skill in skills:
        cleaned = skill.strip().lower()
        if cleaned and cleaned not in exclude_phrases:
            unique_skills.add(cleaned)

# Convert to sorted list
sorted_skills = sorted(unique_skills)

# Write to skills.json
with open('skills_3.json', 'w', encoding='utf-8') as out_file:
    json.dump(sorted_skills, out_file, indent=4)

print(f"✅ Extracted {len(sorted_skills)} unique skills to skills.json")
# Out:
# ✅ Extracted 860 unique skills to skills.json

# %%
import json
import re

# Load jobs.json
with open('jobs.json', 'r', encoding='utf-8') as f:
    job_data = json.load(f)

unique_skills = set()

# Optional: Add known perks to exclude
exclude_phrases = {
    "free snacks", "free snacks & beverages", "informal dress code",
    "5 days a week", "health insurance", "certificate",
    "letter of recommendation", "job offer", "cab/transportation facility"
}

for job in job_data:
    skills_field = job.get("skills", [])
    extracted = []

    if isinstance(skills_field, list):
        for entry in skills_field:
            if isinstance(entry, str):
                # Split by comma, pipe, or newline
                split_skills = re.split(r'[,\n|]', entry)
                extracted.extend(split_skills)
    elif isinstance(skills_field, str):
        extracted = re.split(r'[,\n|]', skills_field)

    # Clean and filter
    for skill in extracted:
        skill = skill.strip().lower()
        if skill and skill not in exclude_phrases:
            unique_skills.add(skill)

# Write unique, sorted skills to skills.json
sorted_skills = sorted(unique_skills)

with open('skills_4.json', 'w', encoding='utf-8') as out_file:
    json.dump(sorted_skills, out_file, indent=4)

print(f"✅ Extracted {len(sorted_skills)} unique cleaned skills.")
# Out:
# ✅ Extracted 860 unique cleaned skills.

# %%
import csv
import json

csv_file_path = 'job_details.csv'
json_file_path = 'job_details.json'

output_data = []

with open(csv_file_path, mode='r', encoding='utf-8') as csv_file:
    reader = csv.DictReader(csv_file)
    for row in reader:
        job = {
            "title": row["Job Title"],
            "skills": [skill.strip().lower() for skill in row["Skills Required"].split('|')]
        }
        output_data.append(job)

with open(json_file_path, mode='w', encoding='utf-8') as json_file:
    json.dump(output_data, json_file, indent=4)

print(f"JSON file created at: {json_file_path}")
# Out:
# JSON file created at: job_details.json

# %% [markdown]
# [
#     {
#         "title": "Data Scientist",
#         "description": "Work with data to develop machine learning models.",
#         "skills": ["python", "machine learning", "deep learning", "tensorflow", "sql"]
#     },
#     {
#         "title": "Frontend Developer",
#         "description": "Develop and maintain user interfaces for web applications.",
#         "skills": ["html", "css", "javascript", "react"]
#     },
#     {
#         "title": "Backend Developer",
#         "description": "Develop server-side applications and APIs.",
#         "skills": ["python", "java", "nodejs", "aws", "sql"]
#     },
#     {
#         "title": "Full Stack Developer",
#         "description": "Work on both frontend and backend development.",
#         "skills": ["python", "javascript", "react", "nodejs", "docker"]
#     }
# ]

# %%
import csv

csv_file_path = 'job_details.csv'

with open(csv_file_path, mode='r', encoding='utf-8') as csv_file:
    reader = csv.reader(csv_file)
    headers = next(reader)
    print("CSV headers:", headers)
# Out:
# CSV headers: ['Job Title', 'Company Name', 'Location', 'Start Date', 'CTC (Annual)', 'Experience', 'Apply By', 'Skills Required', 'Perks']
